# %%
import os, random, cv2, Classify
import numpy as np
from matplotlib import pyplot as plt

oldpwd = os.getcwd()
os.chdir('..')
os.chdir('../resources')
pwd = os.getcwd()
os.chdir(oldpwd)

# 1. Load image(s)
img_name = random.choice(os.listdir(pwd + '/images/1'))
print(img_name)
img = cv2.imread(pwd + '/images/1/' + img_name, 0)
    
# 2. Load models
classifiers = Classify.load_svm(pwd + '/SVM')
print(classifiers)
plt.imshow(img, cmap='gray')
# Out:
# 19374_2021-02-13_19.39_19358347.png
# {'head': SVC(probability=True), 'spine': SVC(probability=True), 'leg': SVC(probability=True), 'arm': SVC(probability=True), 'foot': SVC(probability=True), 'hand': SVC(probability=True)}

# %% [markdown]
# # 3. Analyse image

# %%
# %%time
wanted_classifiers = ['head','spine']  # The keys you want
wanted_classifiers = dict((k, classifiers[k]) for k in wanted_classifiers if k in classifiers)
feat_image, result, pred = Classify.analyse_image(img, classifiers,  crop_thresh=0.2, blur_size=10, bright_strength=1, sharp_strength=1,
                               square_step=True, windows=[(64, 64), (96, 96), (128, 128), (192, 192)], window_stride=16, pred_threshold = 0.99)
print(len(pred), len(result))
result
# Out:
# 1996 1
# Wall time: 34.4 s
#        x    y window_size                                             window  \
# 1308  92  294  (128, 128)  [[44, 46, 47, 48, 48, 48, 47, 46, 46, 46, 46, ...
#
#                                                     hog     head     spine  \
# 1308  [[0.10354200428984278, 0.06423183419217848, 0....  0.99804  0.002108
#
#           leg       arm      foot      hand highest  highest_pred
# 1308  0.00585  0.003534  0.003031  0.003874    head       0.99804

# %%
plt.imshow(feat_image)

# %%
from Classify import iou_value

r = result.reset_index(drop=True)
i=0
to_drop = []
while i < len(r):
    for idx1 in range(i+1, len(r)):
        row = r.iloc[i]
        row1 = r.iloc[idx1]
        if i==idx1:
            continue

        print(iou_value(row, row1))
        if iou_value(row, row1)> 0.5:
            if row['highest_pred'] > row1['highest_pred']:
                to_drop.append(idx1)
            else:
                to_drop.append(i)
            i = 0
            break
    i = i+1
r = r.drop(to_drop, axis=0)
r
# Out:
#     x    y window_size                                             window  \
# 0  92  294  (128, 128)  [[44, 46, 47, 48, 48, 48, 47, 46, 46, 46, 46, ...
#
#                                                  hog     head     spine  \
# 0  [[0.10354200428984278, 0.06423183419217848, 0....  0.99804  0.002108
#
#        leg       arm      foot      hand highest  highest_pred
# 0  0.00585  0.003534  0.003031  0.003874    head       0.99804

# %%
from Classify import draw_boxes
feat2 = draw_boxes(img, r)
plt.imshow(feat2)
